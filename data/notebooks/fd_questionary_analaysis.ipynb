# %% [markdown]
# Step 0: Import and reading data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# Set display options to 200 columns for better readability
pd.set_option('display.max_columns', 200)

# Read a CSV file into a DataFrame
df = pd.read_csv("Original_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 pd.set_option('display.max_columns', 200)
#       8 # Read a CSV file into a DataFrame
# ----> 9 df = pd.read_csv("Original_data.csv")
#
# File c:\Users\Administratören\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Administratören\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Administratören\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Administratören\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Administratören\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Original_data.csv'

# %% [markdown]
# Step 1: Data Understanding
# - Dataframe shape
# - head and tail
# - dtypes
# - describe

# %%
df.shape
# Out:
# (40, 24)

# %%
df.head(5)
# Out:
#    GENDER  AGE Do you invest in Investment Avenues?  \
# 0  Female   34                                  Yes
# 1  Female   23                                  Yes
# 2    Male   30                                  Yes
# 3    Male   22                                  Yes
# 4  Female   24                                   No
#
#    What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]  \
# 0                                                  1
# 1                                                  4
# 2                                                  3
# 3                                                  2
# 4                                                  2
#
#    What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]  \
# 0                                                  2
# 1                                                  3
# 2                                                  6
# 3                                                  1
# 4                                                  1
#
#    What do you think are the best options for investing your money? (Rank in order of preference) [Debentures]  \
# 0                                                  5
# 1                                                  2
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#    What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds]  \
# 0                                                  3
# 1                                                  1
# 2                                                  2
# 3                                                  7
# 4                                                  6
#
#    What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits]  \
# 0                                                  7
# 1                                                  5
# 2                                                  5
# 3                                                  6
# 4                                                  4
#
#    What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund]  \
# 0                                                  6
# 1                                                  6
# 2                                                  1
# 3                                                  4
# 4                                                  5
#
#    What do you think are the best options for investing your money? (Rank in order of preference) [Gold]  \
# 0                                                  4
# 1                                                  7
# 2                                                  7
# 3                                                  5
# 4                                                  7
#
#   Do you invest in Stock Market?  \
# 0                            Yes
# 1                             No
# 2                            Yes
# 3                            Yes
# 4                             No
#
#   What are the factors considered by you while investing in any instrument?  \
# 0                                            Returns
# 1                                     Locking Period
# 2                                            Returns
# 3                                            Returns
# 4                                            Returns
#
#   What is your investment objective? What is your purpose behind investment?  \
# 0               Capital Appreciation                         Wealth Creation
# 1               Capital Appreciation                         Wealth Creation
# 2               Capital Appreciation                         Wealth Creation
# 3                             Income                         Wealth Creation
# 4                             Income                         Wealth Creation
#
#   How long do you prefer to keep your money in any investment instrument?  \
# 0                                          1-3 years
# 1                                  More than 5 years
# 2                                          3-5 years
# 3                                   Less than 1 year
# 4                                   Less than 1 year
#
#   How often do you monitor your investment?  \
# 0                                   Monthly
# 1                                    Weekly
# 2                                     Daily
# 3                                     Daily
# 4                                     Daily
#
#   How much return do you expect from any investment instrument?  \
# 0                                            20%-30%
# 1                                            20%-30%
# 2                                            20%-30%
# 3                                            10%-20%
# 4                                            20%-30%
#
#   Which investment avenue do you mostly invest in?  \
# 0                                      Mutual Fund
# 1                                      Mutual Fund
# 2                                           Equity
# 3                                           Equity
# 4                                           Equity
#
#   What are your savings objectives? Reasons for investing in Equity Market  \
# 0                   Retirement Plan                   Capital Appreciation
# 1                       Health Care                               Dividend
# 2                   Retirement Plan                   Capital Appreciation
# 3                   Retirement Plan                               Dividend
# 4                   Retirement Plan                   Capital Appreciation
#
#   Reasons for investing in Mutual Funds  \
# 0                        Better Returns
# 1                        Better Returns
# 2                          Tax Benefits
# 3                  Fund Diversification
# 4                        Better Returns
#
#   Reasons for investing in Government Bonds  \
# 0                           Safe Investment
# 1                           Safe Investment
# 2                           Assured Returns
# 3                            Tax Incentives
# 4                           Safe Investment
#
#   Reasons for investing in Fixed Deposits   \
# 0                            Fixed Returns
# 1                      High Interest Rates
# 2                            Fixed Returns
# 3                      High Interest Rates
# 4                                Risk Free
#
#   Your sources of information for investments is
# 0                        Newspapers and Magazines
# 1                           Financial Consultants
# 2                                      Television
# 3                                        Internet
# 4                                        Internet

# %%
df.tail(5)
# Out:
#    GENDER  AGE Do you invest in Investment Avenues?  \
# 35   Male   30                                  Yes
# 36   Male   30                                  Yes
# 37   Male   25                                  Yes
# 38   Male   31                                  Yes
# 39   Male   29                                  Yes
#
#     What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]  \
# 35                                                  1
# 36                                                  2
# 37                                                  5
# 38                                                  2
# 39                                                  4
#
#     What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]  \
# 35                                                  4
# 36                                                  4
# 37                                                  4
# 38                                                  4
# 39                                                  3
#
#     What do you think are the best options for investing your money? (Rank in order of preference) [Debentures]  \
# 35                                                  6
# 36                                                  7
# 37                                                  7
# 38                                                  7
# 39                                                  5
#
#     What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds]  \
# 35                                                  5
# 36                                                  5
# 37                                                  6
# 38                                                  5
# 39                                                  7
#
#     What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits]  \
# 35                                                  3
# 36                                                  1
# 37                                                  1
# 38                                                  3
# 39                                                  2
#
#     What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund]  \
# 35                                                  2
# 36                                                  3
# 37                                                  2
# 38                                                  1
# 39                                                  1
#
#     What do you think are the best options for investing your money? (Rank in order of preference) [Gold]  \
# 35                                                  7
# 36                                                  6
# 37                                                  3
# 38                                                  6
# 39                                                  6
#
#    Do you invest in Stock Market?  \
# 35                            Yes
# 36                            Yes
# 37                            Yes
# 38                            Yes
# 39                            Yes
#
#    What are the factors considered by you while investing in any instrument?  \
# 35                                               Risk
# 36                                            Returns
# 37                                               Risk
# 38                                               Risk
# 39                                            Returns
#
#    What is your investment objective? What is your purpose behind investment?  \
# 35                             Growth                         Wealth Creation
# 36               Capital Appreciation                         Wealth Creation
# 37                             Growth                      Savings for Future
# 38                             Growth                         Wealth Creation
# 39               Capital Appreciation                         Wealth Creation
#
#    How long do you prefer to keep your money in any investment instrument?  \
# 35                                          3-5 years
# 36                                          1-3 years
# 37                                          3-5 years
# 38                                          1-3 years
# 39                                          3-5 years
#
#    How often do you monitor your investment?  \
# 35                                   Monthly
# 36                                   Monthly
# 37                                   Monthly
# 38                                    Weekly
# 39                                   Monthly
#
#    How much return do you expect from any investment instrument?  \
# 35                                            20%-30%
# 36                                            20%-30%
# 37                                            30%-40%
# 38                                            20%-30%
# 39                                            20%-30%
#
#    Which investment avenue do you mostly invest in?  \
# 35                                   Fixed Deposits
# 36                                           Equity
# 37                            Public Provident Fund
# 38                                           Equity
# 39                                   Fixed Deposits
#
#    What are your savings objectives? Reasons for investing in Equity Market  \
# 35                       Health Care                   Capital Appreciation
# 36                   Retirement Plan                   Capital Appreciation
# 37                       Health Care                   Capital Appreciation
# 38                       Health Care                               Dividend
# 39                   Retirement Plan                               Dividend
#
#    Reasons for investing in Mutual Funds  \
# 35                        Better Returns
# 36                        Better Returns
# 37                        Better Returns
# 38                  Fund Diversification
# 39                        Better Returns
#
#    Reasons for investing in Government Bonds  \
# 35                           Assured Returns
# 36                           Assured Returns
# 37                           Safe Investment
# 38                           Assured Returns
# 39                           Safe Investment
#
#    Reasons for investing in Fixed Deposits   \
# 35                            Fixed Returns
# 36                                Risk Free
# 37                            Fixed Returns
# 38                            Fixed Returns
# 39                            Fixed Returns
#
#    Your sources of information for investments is
# 35                           Financial Consultants
# 36                        Newspapers and Magazines
# 37                           Financial Consultants
# 38                        Newspapers and Magazines
# 39                           Financial Consultants

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   GENDER                                                                                                                  40 non-null     str
#  1   AGE                                                                                                                     40 non-null     int64
#  2   Do you invest in Investment Avenues?                                                                                    40 non-null     str
#  3   What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]           40 non-null     int64
#  4   What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]          40 non-null     int64
#  5   What do you think are the best options for investing your money? (Rank in order of preference) [Debentures]             40 non-null     int64
#  6   What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds]       40 non-null     int64
#  7   What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits]         40 non-null     int64
#  8   What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund]  40 non-null     int64
#  9   What do you think are the best options for investing your money? (Rank in order of preference) [Gold]                   40 non-null     int64
#  10  Do you invest in Stock Market?                                                                                          40 non-null     str
#  11  What are the factors considered by you while investing in any instrument?                                               40 non-null     str
#  12  What is your investment objective?                                                                                      40 non-null     str
#  13  What is your purpose behind investment?                                                                                 40 non-null     str
#  14  How long do you prefer to keep your money in any investment instrument?                                                 40 non-null     str
#  15  How often do you monitor your investment?                                                                               40 non-null     str
#  16  How much return do you expect from any investment instrument?                                                           40 non-null     str
#  17  Which investment avenue do you mostly invest in?                                                                        40 non-null     str
#  18  What are your savings objectives?                                                                                       40 non-null     str
#  19  Reasons for investing in Equity Market                                                                                  40 non-null     str
#  20  Reasons for investing in Mutual Funds                                                                                   40 non-null     str
#  21  Reasons for investing in Government Bonds                                                                               40 non-null     str
#  22  Reasons for investing in Fixed Deposits                                                                                 40 non-null     str
#  23  Your sources of information for investments is                                                                          40 non-null     str
# dtypes: int64(8), str(16)
# memory usage: 7.6 KB

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'Do you invest in Investment Avenues?',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Debentures]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Gold]',
#        'Do you invest in Stock Market?',
#        'What are the factors considered by you while investing in any instrument?',
#        'What is your investment objective?',
#        'What is your purpose behind investment?',
#        'How long do you prefer to keep your money in any investment instrument?',
#        'How often do you monitor your investment?',
#        'How much return do you expect from any investment instrument?',
#        'Which investment avenue do you mostly invest in?',
#        'What are your savings objectives?',
#        'Reasons for investing in Equity Market',
#        'Reasons for investing in Mutual Funds',
#        'Reasons for investing in Government Bonds',
#        'Reasons for investing in Fixed Deposits ',
#        'Your sources of information for investments is '],
#       dtype='str')

# %%
df.dtypes
# Out:
# GENDER                                                                                                                      str
# AGE                                                                                                                       int64
# Do you invest in Investment Avenues?                                                                                        str
# What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]             int64
# What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]            int64
# What do you think are the best options for investing your money? (Rank in order of preference) [Debentures]               int64
# What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds]         int64
# What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits]           int64
# What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund]    int64
# What do you think are the best options for investing your money? (Rank in order of preference) [Gold]                     int64
# Do you invest in Stock Market?                                                                                              str
# What are the factors considered by you while investing in any instrument?                                                   str
# What is your investment objective?                                                                                          str
# What is your purpose behind investment?                                                                                     str
# How long do you prefer to keep your money in any investment instrument?                                                     str
# How often do you monitor your investment?                                                                                   str
# How much return do you expect from any investment instrument?                                                               str
# Which investment avenue do you mostly invest in?                                                                            str
# What are your savings objectives?                                                                                           str
# Reasons for investing in Equity Market                                                                                      str
# Reasons for investing in Mutual Funds                                                                                       str
# Reasons for investing in Government Bonds                                                                                   str
# Reasons for investing in Fixed Deposits                                                                                     str
# Your sources of information for investments is                                                                              str
# dtype: object

# %%
df.describe()
# Out:
#              AGE  \
# count  40.000000
# mean   27.800000
# std     3.560467
# min    21.000000
# 25%    25.750000
# 50%    27.000000
# 75%    30.000000
# max    35.000000
#
#        What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]  \
# count                                          40.000000
# mean                                            2.550000
# std                                             1.197219
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             7.000000
#
#        What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]  \
# count                                          40.000000
# mean                                            3.475000
# std                                             1.131994
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             6.000000
#
#        What do you think are the best options for investing your money? (Rank in order of preference) [Debentures]  \
# count                                          40.000000
# mean                                            5.750000
# std                                             1.675617
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             6.500000
# 75%                                             7.000000
# max                                             7.000000
#
#        What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds]  \
# count                                          40.000000
# mean                                            4.650000
# std                                             1.369072
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             7.000000
#
#        What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits]  \
# count                                          40.000000
# mean                                            3.575000
# std                                             1.795828
# min                                             1.000000
# 25%                                             2.750000
# 50%                                             3.500000
# 75%                                             5.000000
# max                                             7.000000
#
#        What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund]  \
# count                                          40.000000
# mean                                            2.025000
# std                                             1.609069
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.250000
# max                                             6.000000
#
#        What do you think are the best options for investing your money? (Rank in order of preference) [Gold]
# count                                          40.000000
# mean                                            5.975000
# std                                             1.143263
# min                                             2.000000
# 25%                                             6.000000
# 50%                                             6.000000
# 75%                                             7.000000
# max                                             7.000000

# %% [markdown]
# Step 2: Data preparation
# - Copy the dataset
# - Identifying duplicated columns
# - Renaming Colomns
# - Search missing values

# %%
# create a copy of the dataset to work on it without affecting the original dataset
# copy all columns and rows because I am going to analyse full dataset
df = df.copy()

# %%
# Check for duplicates
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
# Check which rows are duplicates
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [GENDER, AGE, Do you invest in Investment Avenues?, What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds], What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market], What do you think are the best options for investing your money? (Rank in order of preference) [Debentures], What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds], What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits], What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund], What do you think are the best options for investing your money? (Rank in order of preference) [Gold], Do you invest in Stock Market?, What are the factors considered by you while investing in any instrument?, What is your investment objective?, What is your purpose behind investment?, How long do you prefer to keep your money in any investment instrument?, How often do you monitor your investment?, How much return do you expect from any investment instrument?, Which investment avenue do you mostly invest in?, What are your savings objectives?, Reasons for investing in Equity Market, Reasons for investing in Mutual Funds, Reasons for investing in Government Bonds, Reasons for investing in Fixed Deposits , Your sources of information for investments is ]
# Index: []

# %%
# Rename colomns
df = df.rename(columns={'AGE':'Age','GENDER':'Gender',
       'Do you invest in Investment Avenues?':'Investment_Avenues',
       'What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]': 'Mutual_Funds',
       'What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]': 'Equity_Market',
       'What do you think are the best options for investing your money? (Rank in order of preference) [Debentures]': 'Debentures',
       'What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds]': 'Government_Bonds',
       'What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits]': 'Fixed_Deposits',
       'What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund]': 'Public_Provident_Fund',
       'What do you think are the best options for investing your money? (Rank in order of preference) [Gold]': 'Gold',
       'Do you invest in Stock Market?': 'Stock_Market',
       'What are the factors considered by you while investing in any instrument?': 'Investment_Factors',
       'What is your investment objective?': 'Investment_Objective',
       'What is your purpose behind investment?': 'Investment_Purpose',
       'How long do you prefer to keep your money in any investment instrument?': 'Investment_Horizon',
       'How often do you monitor your investment?': 'Monitoring_Frequency',
       'How much return do you expect from any investment instrument?': 'Expected_Return',
       'Which investment avenue do you mostly invest in?': 'Preferred_Investment_Avenue',
       'What are your savings objectives?': 'Savings_Objectives',
       'Reasons for investing in Equity Market': 'Reasons_for_Equity_Market',
       'Reasons for investing in Mutual Funds': 'Reasons_for_Mutual_Funds',
       'Reasons for investing in Government Bonds': 'Reasons_for_Government_Bonds',
       'Reasons for investing in Fixed Deposits ': 'Reasons_for_Fixed_Deposits ',
       'Your sources of information for investments is ': 'Sources_of_Information'})

# %%
df.head()
# Out:
#    Gender  Age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  Public_Provident_Fund  Gold Stock_Market  \
# 0                 3               7                      6     4          Yes
# 1                 1               5                      6     7           No
# 2                 2               5                      1     7          Yes
# 3                 7               6                      4     5          Yes
# 4                 6               4                      5     7           No
#
#   Investment_Factors  Investment_Objective Investment_Purpose  \
# 0            Returns  Capital Appreciation    Wealth Creation
# 1     Locking Period  Capital Appreciation    Wealth Creation
# 2            Returns  Capital Appreciation    Wealth Creation
# 3            Returns                Income    Wealth Creation
# 4            Returns                Income    Wealth Creation
#
#   Investment_Horizon Monitoring_Frequency Expected_Return  \
# 0          1-3 years              Monthly         20%-30%
# 1  More than 5 years               Weekly         20%-30%
# 2          3-5 years                Daily         20%-30%
# 3   Less than 1 year                Daily         10%-20%
# 4   Less than 1 year                Daily         20%-30%
#
#   Preferred_Investment_Avenue Savings_Objectives Reasons_for_Equity_Market  \
# 0                 Mutual Fund    Retirement Plan      Capital Appreciation
# 1                 Mutual Fund        Health Care                  Dividend
# 2                      Equity    Retirement Plan      Capital Appreciation
# 3                      Equity    Retirement Plan                  Dividend
# 4                      Equity    Retirement Plan      Capital Appreciation
#
#   Reasons_for_Mutual_Funds Reasons_for_Government_Bonds  \
# 0           Better Returns              Safe Investment
# 1           Better Returns              Safe Investment
# 2             Tax Benefits              Assured Returns
# 3     Fund Diversification               Tax Incentives
# 4           Better Returns              Safe Investment
#
#   Reasons_for_Fixed_Deposits     Sources_of_Information
# 0               Fixed Returns  Newspapers and Magazines
# 1         High Interest Rates     Financial Consultants
# 2               Fixed Returns                Television
# 3         High Interest Rates                  Internet
# 4                   Risk Free                  Internet

# %%
# Check for missing values
df.isna().sum()
# Out:
# Gender                          0
# Age                             0
# Investment_Avenues              0
# Mutual_Funds                    0
# Equity_Market                   0
# Debentures                      0
# Government_Bonds                0
# Fixed_Deposits                  0
# Public_Provident_Fund           0
# Gold                            0
# Stock_Market                    0
# Investment_Factors              0
# Investment_Objective            0
# Investment_Purpose              0
# Investment_Horizon              0
# Monitoring_Frequency            0
# Expected_Return                 0
# Preferred_Investment_Avenue     0
# Savings_Objectives              0
# Reasons_for_Equity_Market       0
# Reasons_for_Mutual_Funds        0
# Reasons_for_Government_Bonds    0
# Reasons_for_Fixed_Deposits      0
# Sources_of_Information          0
# dtype: int64

# %% [markdown]
# Step 3: Feature understanding
# - Age - pie chart
# - Gender  - pie chart
# - Respondents' interest in Investment Avenues - pie chart
# - Respondents' interest in Stock Market - pie chart
# - Average rank given by Respondents to Investment Avenues - barh plot
# - Average rank given by Younger Respondents to Investment Avenues - barh plot
# - Most common answers given by Respondents separated by Gender and their respective occurence percentage ratio - barh plot
# - Most common answers given by Younger Respondents separated by Gender and their respective occurence percentage ratio - barh plot

# %%
# Gender distribution - pie chart
ax = df['Gender'].value_counts() \
.plot(kind='pie',
    title='Gender Distribution of Survey Participants',
    autopct='%1.1f%%',
    startangle=90,
    counterclock=False) 
plt.tight_layout()
plt.show()

# %%
# Age distribution - pie chart
ax = df['Age'].value_counts() \
.sort_index() \
.plot(
    kind='pie',
    title='Age Distribution of Survey Participants',
    autopct='%1.1f%%',
    pctdistance=0.87,
    startangle=90,
    counterclock=False) 

# Adjust percentage texts inside sectors of the pie chart
for text in ax.texts:
    if '%' in text.get_text():
        text.set_fontsize(7)
        text.set_fontstyle('italic')
        text.set_color('white')

plt.tight_layout()
plt.show()

# %%
# Respondents' interest in Investment Avenues - pie chart
df_ia = df.groupby('Investment_Avenues')[['Gender']].value_counts()
ax = df_ia.plot(kind='pie',
    title='Respondents responses to opportunities in Investment Avenues',
    autopct='%1.1f%%',
    pctdistance=0.7,

        # Custom colors
    colors=["#ff9ca2", "#609d4d", "#8fe079"],

    startangle=65) 

plt.tight_layout()
plt.show()

# %%
# Respondents' interest in Stock Market - pie chart
df_sm = df.groupby('Stock_Market')[['Gender']].value_counts()

ax = df_sm.plot(kind='pie',
    title='Respondents responses to opportunities in Stock Market',
    autopct='%1.1f%%',
    pctdistance=0.7,

    # Custom colors
    colors=["#ff9ca2", "#f14b7d", "#609d4d", "#8fe079"],

    startangle=45) 



plt.tight_layout()
plt.show()

# %%
# Average ranking of Investment avenues - bar plot

cols = ['Mutual_Funds', 'Equity_Market',
        'Debentures', 'Government_Bonds', 'Fixed_Deposits',
        'Public_Provident_Fund', 'Gold']

grouped = df.groupby('Gender')[cols].mean()

ax = grouped.T.plot(
    kind='barh',
    title='Investment Avenues Average Ranking'
)

ax.set_xlabel('Average Score (Lower is More Preferred)')
ax.set_ylabel('Investment Type')

plt.tight_layout()
plt.show()

# %%
# Average ranking of Investment avenues by respondents under 25 y.o. - bar plot

cols = ['Mutual_Funds', 'Equity_Market',
        'Debentures', 'Government_Bonds', 'Fixed_Deposits',
        'Public_Provident_Fund', 'Gold']

# Filter the DataFrame to include only respondents under 25 years old
df_under_25 = df[df['Age'] <= 25]

grouped = df_under_25.groupby('Gender')[cols].mean()
ax = grouped.T.plot(
    kind='barh',
    title='Investment Avenues Average Ranking by Respondents <= 25 y.o.'
)

ax.set_xlabel('Average Score (Lower is More Preferred)')
ax.set_ylabel('Investment Type')

plt.tight_layout()
plt.show()

# %%
# Most common answers given by Respondents separated by Gender and their respective occurence percentage ratio - bar plot

results = []

for column in df.columns[11:]:
    row = {'Column': column}

    for gender in ['Male', 'Female']:
        df_gender = df[df['Gender'] == gender]

        vc = df_gender[column].value_counts()

        most_common = vc.idxmax()
        pct = math.ceil(100 * vc.max() / len(df_gender))

        row[f'{gender}_Answer'] = most_common
        row[f'{gender}_Ratio'] = pct

    results.append(row)

df_responses = pd.DataFrame(results).set_index('Column')

# labels

def make_label(row):
    if row['Male_Answer'] == row['Female_Answer']:
        return row['Male_Answer']
    else:
        return f"M: {row['Male_Answer']} | F: {row['Female_Answer']}"

df_responses['Answer_Label'] = df_responses.apply(make_label, axis=1)

# Plot

# import MultipleLocator for better control over y-axis ticks  
from matplotlib.ticker import MultipleLocator


plot_df = df_responses[['Male_Ratio', 'Female_Ratio']].rename(
    columns={
        'Male_Ratio': 'Men',
        'Female_Ratio': 'Women'
    }
)

ax = plot_df.plot(
    kind='barh',
    title='Most Common Answers by Gender',
    figsize=(14, 6)
)

ax.set_xlabel('Ratio (%)')
ax.set_ylabel('Questions')

# Grid only on x-axis
ax.xaxis.set_major_locator(MultipleLocator(20))
ax.xaxis.set_minor_locator(MultipleLocator(10))

ax.grid(which='major', linestyle='--', linewidth=0.6)
ax.grid(which='minor', linestyle=':', linewidth=0.3, alpha=0.5)

# Add x-axis labels for better readability
for i, label in enumerate(df_responses['Answer_Label']):
    ax.text(
        plot_df.iloc[i].max() + 1,  # x-position (right of bar)
        i,                           # y-position
        label,
        va='center',
        fontsize=7
    )
plt.tight_layout()
plt.show()

# %%
# Most common answers given by Young Respondents under 25 y.o. separated by Gender and their respective occurence percentage ratio - bar plot

results = []

# Filter the DataFrame to include only respondents under 25 years old
df_under_25 = df[df['Age'] <= 25]

for column in df_under_25.columns[11:]:
    row = {'Column': column}

    for gender in ['Male', 'Female']:
        df_gender = df_under_25[df_under_25['Gender'] == gender]

        vc = df_gender[column].value_counts()

        most_common = vc.idxmax()
        pct = math.ceil(100 * vc.max() / len(df_gender))

        row[f'{gender}_Answer'] = most_common
        row[f'{gender}_Ratio'] = pct

    results.append(row)

df_responses = pd.DataFrame(results).set_index('Column')

# labels

def make_label(row):
    if row['Male_Answer'] == row['Female_Answer']:
        return row['Male_Answer']
    else:
        return f"M: {row['Male_Answer']} | F: {row['Female_Answer']}"

df_responses['Answer_Label'] = df_responses.apply(make_label, axis=1)

# Plot

# import MultipleLocator for better control over y-axis ticks  
from matplotlib.ticker import MultipleLocator


plot_df = df_responses[['Male_Ratio', 'Female_Ratio']].rename(
    columns={
        'Male_Ratio': 'Men',
        'Female_Ratio': 'Women'
    }
)

ax = plot_df.plot(
    kind='barh',
    title='Most Common Answers of respondents <= 25 y.o. by Gender',
    figsize=(14, 6)
)

ax.set_xlabel('Ratio (%)')
ax.set_ylabel('Questions')

# Grid only on x-axis
ax.xaxis.set_major_locator(MultipleLocator(20))
ax.xaxis.set_minor_locator(MultipleLocator(10))

ax.grid(which='major', linestyle='--', linewidth=0.6)
ax.grid(which='minor', linestyle=':', linewidth=0.3, alpha=0.5)

# Add x-axis labels for better readability
for i, label in enumerate(df_responses['Answer_Label']):
    ax.text(
        plot_df.iloc[i].max() + 1,  # x-position (right of bar)
        i,                           # y-position
        label,
        va='center',
        fontsize=7
    )
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 results = []
#       5 # Filter the DataFrame to include only respondents under 25 years old
# ----> 6 df_under_25 = df[df['Age'] <= 25]
#       8 for column in df_under_25.columns[11:]:
#       9     row = {'Column': column}
#
# NameError: name 'df' is not defined
